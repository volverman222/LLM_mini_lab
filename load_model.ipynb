# %%
from helper_functions import generate
import torch
from pretraining import text_to_token_ids
import tiktoken
import torch
from pretraining import token_ids_to_text

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
from Transformer_arquitectures import GPTModel
# If the `previous_chapters.py` file is not available locally,
# you can import it from the `llms-from-scratch` PyPI package.
# For details, see: https://github.com/rasbt/LLMs-from-scratch/tree/main/pkg
# E.g.,
# from llms_from_scratch.ch04 import GPTModel

GPT_CONFIG_124M = {
    "vocab_size": 50257,   # Vocabulary size
    "context_length": 256, # Shortened context length (orig: 1024)
    "emb_dim": 768,        # Embedding dimension
    "n_heads": 12,         # Number of attention heads
    "n_layers": 12,        # Number of layers
    "drop_rate": 0.1,      # Dropout rate
    "qkv_bias": False      # Query-key-value bias
}

torch.manual_seed(123)
model = GPTModel(GPT_CONFIG_124M)
model.eval();  # Disable dropout during inference

# %%
model_path ="/Users/oscarmanuelhernandezhernandez/Downloads/gpt2-fineweb.pth"

# %%
model.load_state_dict(torch.load(
    model_path,
    map_location="cpu",
    weights_only=True,
))
# Out:
# <All keys matched successfully>

# %%
# Hacemos un poco de inferencia 

ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer),
    max_new_tokens=25,
    context_size=GPT_CONFIG_124M["context_length"],
    top_k=50,
    temperature=1.5,
)
print(token_ids_to_text(ids, tokenizer))
# Out:
# Every effort moves you see, and help you are even if your eyes?<|endoftext|>By your body's words so to make example in both, and
